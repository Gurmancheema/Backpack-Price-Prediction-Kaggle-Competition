# %% [markdown]
# # 1. Importing libraries & reading cleaned training data

# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('data/cleaned_train_dataset.csv')
df.drop('Unnamed: 0',axis=1,inplace=True)
df.head(20)
# Out:
#     Unnamed: 0  id         Brand   Material    Size  Compartments  \
# 0            0   0      Jansport    Leather  Medium           7.0
# 1            1   1      Jansport     Canvas   Small          10.0
# 2            2   2  Under Armour    Leather   Small           2.0
# 3            3   3          Nike      Nylon   Small           8.0
# 4            4   4        Adidas     Canvas  Medium           1.0
# 5            7   7          Puma     Canvas   Small           1.0
# 6            8   8  Under Armour  Polyester  Medium           8.0
# 7            9   9  Under Armour      Nylon  Medium           2.0
# 8           12  12        Adidas      Nylon  Medium           5.0
# 9           13  13  Under Armour    Leather  Medium           8.0
# 10          14  14          Nike  Polyester   Small          10.0
# 11          15  15        Adidas    Leather   Small          10.0
# 12          16  16          Puma  Polyester   Large           2.0
# 13          17  17          Puma      Nylon   Large           1.0
# 14          18  18          Nike     Canvas   Small           5.0
# 15          19  19        Adidas     Canvas   Small           3.0
# 16          20  20        Adidas    Leather   Small           3.0
# 17          23  23      Jansport    Leather  Medium           1.0
# 18          24  24      Jansport      Nylon   Large           1.0
# 19          25  25        Adidas      Nylon  Medium           2.0
#
#    Laptop Compartment Waterproof      Style  Color  Weight Capacity (kg)  \
# 0                 Yes         No       Tote  Black             11.611723
# 1                 Yes        Yes  Messenger  Green             27.078537
# 2                 Yes         No  Messenger    Red             16.643760
# 3                 Yes         No  Messenger  Green             12.937220
# 4                 Yes        Yes  Messenger  Green             17.749338
# 5                 Yes        Yes   Backpack   Blue             21.488864
# 6                 Yes         No       Tote   Gray             10.207780
# 7                 Yes        Yes  Messenger   Pink             15.895100
# 8                 Yes         No   Backpack   Blue             15.872050
# 9                  No         No       Tote    Red             26.079409
# 10                 No        Yes       Tote  Green             14.744147
# 11                Yes         No       Tote  Green              7.934018
# 12                 No        Yes   Backpack   Blue             18.988774
# 13                 No        Yes       Tote   Gray             15.533611
# 14                 No         No  Messenger  Black             26.116081
# 15                 No        Yes       Tote  Green             26.262637
# 16                Yes        Yes  Messenger   Blue             28.560905
# 17                Yes         No       Tote   Blue             12.571250
# 18                 No         No   Backpack    Red             25.936886
# 19                 No         No  Messenger  Green             22.898809
#
#         Price
# 0   112.15875
# 1    68.88056
# 2    39.17320
# 3    80.60793
# 4    86.02312
# 5    27.15815
# 6    25.98652
# 7    38.48741
# 8   111.80791
# 9    26.37209
# 10   75.96081
# 11   37.78611
# 12   69.61682
# 13   68.24736
# 14   59.10262
# 15   59.18372
# 16  112.27855
# 17  106.83635
# 18   80.95478
# 19   90.80347

# %%
df.describe()
# Out:
#                   id   Compartments  Weight Capacity (kg)          Price
# count  246686.000000  246686.000000         246686.000000  246686.000000
# mean   150048.329557       5.448984             18.016588      81.582528
# std     86604.008063       2.886397              6.964860      38.939976
# min         0.000000       1.000000              5.000000      15.000000
# 25%     75041.250000       3.000000             12.076210      47.759870
# 50%    150108.500000       5.000000             18.048580      81.226310
# 75%    224949.750000       8.000000             23.990489     115.006480
# max    299999.000000      10.000000             29.999796     150.000000

# %% [markdown]
# # 2. Exploratory Data Analysis

# %% [markdown]
# ### 2.1 Countplot of Categorical columns

# %%
categorical_cols = df.select_dtypes('object','category').columns.tolist()
for i in categorical_cols:
    plt.figure(figsize= (8,6))
    sb.countplot(x=df[i])
    plt.title(f"Countplot of {i}")
    plt.show()
